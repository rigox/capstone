# %%
import pandas as pd

# %%
apple =  pd.read_csv("AAPL (1).csv")
msft  = pd.read_csv("MSFT (1).csv")
amzn   = pd.read_csv("AMZN.csv")
intc = pd.read_csv("INTC.csv")
FB =  pd.read_csv("FB.csv")
GOOG =  pd.read_csv("GOOG.csv")

# %%
msft.head()
# Out:
#          Date       Open       High        Low      Close  Adj Close  \
# 0  2012-05-01  32.049999  32.340000  28.639999  29.190001  24.902672
# 1  2012-06-01  28.760000  31.139999  28.320000  30.590000  26.268282
# 2  2012-07-01  30.620001  31.049999  28.540001  29.469999  25.306519
# 3  2012-08-01  29.590000  30.959999  28.969999  30.820000  26.465794
# 4  2012-09-01  30.450001  31.610001  29.740000  29.760000  25.724844
#
#        Volume
# 0  1014372600
# 1   973131400
# 2   846604100
# 3   671748400
# 4   893107700

# %%
# we just need to get the name , data  and close columsn

cols =   ['Date'  ,  'Close']
apple =  apple[cols]

# %%
apple["Name"] =  "AAPL"

# %%
msft =  msft[cols]
msft["Name"] = "MSFT"

# %%
amzn  = amzn[cols]
amzn["Name"] =  "AMZN"

# %%
intc  = intc[cols]
intc["Name"]  = "INTC"

# %%
FB  =  FB[cols]
FB["Name"] =  "FB"

# %%
GOOG  =  GOOG[cols]
GOOG["Name"]  = "GOOG"

# %%
apple.to_csv("AAPL_1.csv" , index=False)

# %%
msft.to_csv("MSFT_1.csv" , index=False)

# %%
amzn.to_csv("AMZN_1.csv" , index=False)

# %%
intc.to_csv("INTC_1.csv", index=False)

# %%
FB.to_csv("FB_1.csv" , index=False)

# %%
GOOG.to_csv("GOOG_1.csv" , index=False)

# %%
a  =  pd.read_csv("AAPL_1.csv")

# %%
a.head()
# Out:
#          Date      Close  Name
# 0  2012-05-01  82.532860  AAPL
# 1  2012-06-01  83.428574  AAPL
# 2  2012-07-01  87.251427  AAPL
# 3  2012-08-01  95.034286  AAPL
# 4  2012-09-01  95.300003  AAPL

# %%
msft.head()
# Out:
#          Date      Close  Name
# 0  2012-05-01  29.190001  MSFT
# 1  2012-06-01  30.590000  MSFT
# 2  2012-07-01  29.469999  MSFT
# 3  2012-08-01  30.820000  MSFT
# 4  2012-09-01  29.760000  MSFT

# %%
a = apple
len(a)
# Out:
# 71

# %%
a.append(msft)
# Out:
#           Date       Close  Name
# 0   2012-05-01   82.532860  AAPL
# 1   2012-06-01   83.428574  AAPL
# 2   2012-07-01   87.251427  AAPL
# 3   2012-08-01   95.034286  AAPL
# 4   2012-09-01   95.300003  AAPL
# 5   2012-10-01   85.045715  AAPL
# 6   2012-11-01   83.611427  AAPL
# 7   2012-12-01   76.024284  AAPL
# 8   2013-01-01   65.070000  AAPL
# 9   2013-02-01   63.057144  AAPL
# 10  2013-03-01   63.237144  AAPL
# 11  2013-04-01   63.254284  AAPL
# 12  2013-05-01   64.247147  AAPL
# 13  2013-06-01   56.647144  AAPL
# 14  2013-07-01   64.647141  AAPL
# 15  2013-08-01   69.602859  AAPL
# 16  2013-09-01   68.107140  AAPL
# 17  2013-10-01   74.671425  AAPL
# 18  2013-11-01   79.438568  AAPL
# 19  2013-12-01   80.145714  AAPL
# 20  2014-01-01   71.514282  AAPL
# 21  2014-02-01   75.177139  AAPL
# 22  2014-03-01   76.677139  AAPL
# 23  2014-04-01   84.298569  AAPL
# 24  2014-05-01   90.428574  AAPL
# 25  2014-06-01   92.930000  AAPL
# 26  2014-07-01   95.599998  AAPL
# ...

# %%
a.append(amzn)
# Out:
#           Date        Close  Name
# 0   2012-05-01    82.532860  AAPL
# 1   2012-06-01    83.428574  AAPL
# 2   2012-07-01    87.251427  AAPL
# 3   2012-08-01    95.034286  AAPL
# 4   2012-09-01    95.300003  AAPL
# 5   2012-10-01    85.045715  AAPL
# 6   2012-11-01    83.611427  AAPL
# 7   2012-12-01    76.024284  AAPL
# 8   2013-01-01    65.070000  AAPL
# 9   2013-02-01    63.057144  AAPL
# 10  2013-03-01    63.237144  AAPL
# 11  2013-04-01    63.254284  AAPL
# 12  2013-05-01    64.247147  AAPL
# 13  2013-06-01    56.647144  AAPL
# 14  2013-07-01    64.647141  AAPL
# 15  2013-08-01    69.602859  AAPL
# 16  2013-09-01    68.107140  AAPL
# 17  2013-10-01    74.671425  AAPL
# 18  2013-11-01    79.438568  AAPL
# 19  2013-12-01    80.145714  AAPL
# 20  2014-01-01    71.514282  AAPL
# 21  2014-02-01    75.177139  AAPL
# 22  2014-03-01    76.677139  AAPL
# 23  2014-04-01    84.298569  AAPL
# 24  2014-05-01    90.428574  AAPL
# 25  2014-06-01    92.930000  AAPL
# ...

# %%
a.append(intc)
# Out:
#           Date       Close  Name
# 0   2012-05-01   82.532860  AAPL
# 1   2012-06-01   83.428574  AAPL
# 2   2012-07-01   87.251427  AAPL
# 3   2012-08-01   95.034286  AAPL
# 4   2012-09-01   95.300003  AAPL
# 5   2012-10-01   85.045715  AAPL
# 6   2012-11-01   83.611427  AAPL
# 7   2012-12-01   76.024284  AAPL
# 8   2013-01-01   65.070000  AAPL
# 9   2013-02-01   63.057144  AAPL
# 10  2013-03-01   63.237144  AAPL
# 11  2013-04-01   63.254284  AAPL
# 12  2013-05-01   64.247147  AAPL
# 13  2013-06-01   56.647144  AAPL
# 14  2013-07-01   64.647141  AAPL
# 15  2013-08-01   69.602859  AAPL
# 16  2013-09-01   68.107140  AAPL
# 17  2013-10-01   74.671425  AAPL
# 18  2013-11-01   79.438568  AAPL
# 19  2013-12-01   80.145714  AAPL
# 20  2014-01-01   71.514282  AAPL
# 21  2014-02-01   75.177139  AAPL
# 22  2014-03-01   76.677139  AAPL
# 23  2014-04-01   84.298569  AAPL
# 24  2014-05-01   90.428574  AAPL
# 25  2014-06-01   92.930000  AAPL
# 26  2014-07-01   95.599998  AAPL
# ...

# %%
a.append(FB)
# Out:
#           Date       Close  Name
# 0   2012-05-01   82.532860  AAPL
# 1   2012-06-01   83.428574  AAPL
# 2   2012-07-01   87.251427  AAPL
# 3   2012-08-01   95.034286  AAPL
# 4   2012-09-01   95.300003  AAPL
# 5   2012-10-01   85.045715  AAPL
# 6   2012-11-01   83.611427  AAPL
# 7   2012-12-01   76.024284  AAPL
# 8   2013-01-01   65.070000  AAPL
# 9   2013-02-01   63.057144  AAPL
# 10  2013-03-01   63.237144  AAPL
# 11  2013-04-01   63.254284  AAPL
# 12  2013-05-01   64.247147  AAPL
# 13  2013-06-01   56.647144  AAPL
# 14  2013-07-01   64.647141  AAPL
# 15  2013-08-01   69.602859  AAPL
# 16  2013-09-01   68.107140  AAPL
# 17  2013-10-01   74.671425  AAPL
# 18  2013-11-01   79.438568  AAPL
# 19  2013-12-01   80.145714  AAPL
# 20  2014-01-01   71.514282  AAPL
# 21  2014-02-01   75.177139  AAPL
# 22  2014-03-01   76.677139  AAPL
# 23  2014-04-01   84.298569  AAPL
# 24  2014-05-01   90.428574  AAPL
# 25  2014-06-01   92.930000  AAPL
# 26  2014-07-01   95.599998  AAPL
# ...

# %%
a.append(GOOG)
# Out:
#           Date        Close  Name
# 0   2012-05-01    82.532860  AAPL
# 1   2012-06-01    83.428574  AAPL
# 2   2012-07-01    87.251427  AAPL
# 3   2012-08-01    95.034286  AAPL
# 4   2012-09-01    95.300003  AAPL
# 5   2012-10-01    85.045715  AAPL
# 6   2012-11-01    83.611427  AAPL
# 7   2012-12-01    76.024284  AAPL
# 8   2013-01-01    65.070000  AAPL
# 9   2013-02-01    63.057144  AAPL
# 10  2013-03-01    63.237144  AAPL
# 11  2013-04-01    63.254284  AAPL
# 12  2013-05-01    64.247147  AAPL
# 13  2013-06-01    56.647144  AAPL
# 14  2013-07-01    64.647141  AAPL
# 15  2013-08-01    69.602859  AAPL
# 16  2013-09-01    68.107140  AAPL
# 17  2013-10-01    74.671425  AAPL
# 18  2013-11-01    79.438568  AAPL
# 19  2013-12-01    80.145714  AAPL
# 20  2014-01-01    71.514282  AAPL
# 21  2014-02-01    75.177139  AAPL
# 22  2014-03-01    76.677139  AAPL
# 23  2014-04-01    84.298569  AAPL
# 24  2014-05-01    90.428574  AAPL
# 25  2014-06-01    92.930000  AAPL
# ...

# %%
# Out:
# Index(['Date', 'Close', 'Name'], dtype='object')

# %%
a.to
